# %% [markdown]
# <a href="https://colab.research.google.com/github/BMarlinVCU/INFO450/blob/main/lesson3/Day3_APIs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction to APIs

# %%
import requests

# %%
response=requests.get("https://catfact.ninja/fact")

# %%
response.json()
# Out:
# {'fact': 'A cat rubs against people not only to be affectionate but also to mark out its territory with scent glands around its face. The tail area and paws also carry the cat’s scent.',
#  'length': 174}

# %%
data=response.json()
type(data)
# Out:
# dict

# %%
data['fact']
# Out:
# 'A cat rubs against people not only to be affectionate but also to mark out its territory with scent glands around its face. The tail area and paws also carry the cat’s scent.'

# %% [markdown]
# # World API

# %%
#This is going to pull data from world cup API
url = "https://raw.githubusercontent.com/openfootball/worldcup.json/master/2026/worldcup.json"
response=requests.get(url)

# %%
response
data=response.json()
data.keys()
data['matches']
first_match=data['matches'][0]
five_five_match=data['matches'][55]
five_five_match['score']['ft'][0]
# Out:
# 3

# %%
unique_teams = set()

for match in data['matches']:
    if match.get('team1'):
        unique_teams.add(match.get('team1'))
    if match.get('team2'):
        unique_teams.add(match.get('team2'))

# Display the unique team names alphabetically
print("Unique teams found in the data:")
print(sorted(list(unique_teams)))
# Out:
# Unique teams found in the data:
# ['1B', '1C', '1F', '1G', '1H', '1I', '1J', '1K', '1L', '2A', '2B', '2C', '2D', '2E', '2F', '2G', '2H', '2I', '2J', '2K', '2L', '3A/B/C/D/F', '3A/E/H/I/J', '3B/E/F/I/J', '3C/D/F/G/H', '3C/E/F/H/I', '3D/E/I/J/L', '3E/F/G/I/J', '3E/H/I/J/K', 'Algeria', 'Argentina', 'Australia', 'Austria', 'Belgium', 'Bosnia & Herzegovina', 'Brazil', 'Canada', 'Cape Verde', 'Colombia', 'Croatia', 'Curaçao', 'Czech Republic', 'DR Congo', 'Ecuador', 'Egypt', 'England', 'France', 'Germany', 'Ghana', 'Haiti', 'Iran', 'Iraq', 'Ivory Coast', 'Japan', 'Jordan', 'L101', 'L102', 'Mexico', 'Morocco', 'Netherlands', 'New Zealand', 'Norway', 'Panama', 'Paraguay', 'Portugal', 'Qatar', 'Saudi Arabia', 'Scotland', 'Senegal', 'South Africa', 'South Korea', 'Spain', 'Sweden', 'Switzerland', 'Tunisia', 'Turkey', 'USA', 'Uruguay', 'Uzbekistan', 'W100', 'W101', 'W102', 'W73', 'W74', 'W75', 'W76', 'W77', 'W78', 'W79', 'W80', 'W81', 'W82', 'W83', 'W84', 'W85', 'W86', 'W87', 'W88', 'W89', 'W90', 'W91', 'W92', 'W93', 'W94', 'W95', 'W96', 'W97', 'W98', 'W99']

# %% [markdown]
# Using my github as an API

# %%
import requests
url = "https://raw.githubusercontent.com/BMarlinVCU/INFO450/main/parts.json"
response=requests.get(url)
data=response.json()
data['parts'][1]['name']
# Out:
# 'Motherboard'

# %% [markdown]
# # Weather API

# %%
import requests

# API endpoint for historical weather
url = "https://historical-forecast-api.open-meteo.com/v1/forecast"

# Parameters for the request
params = {
"latitude": 40.7128, # Latitude for New York City
"longitude": -74.0060, # Longitude for New York City
"start_date": "2025-06-20", # Start date for the past week
"end_date": "2025-06-26", # End date for the past week
"daily": "temperature_2m_max", # Daily maximum temperature
"timezone": "auto" # Automatically adjust for timezone
}

# Fetch data from the API
response = requests.get(url, params=params)
data = response.json()

# %%
temperatures=data["daily"]['temperature_2m_max']

# %%
temperatures
# Out:
# [29.5, 31.8, 32.4, 36.0, 39.1, 38.2, 30.7]

# %%
sum(temperatures)
# Out:
# 237.7

# %%
del(min)

# %%
min(temperatures)
# Out:
# 29.5

# %%
sum(temperatures)/len(temperatures)
# Out:
# 33.957142857142856
